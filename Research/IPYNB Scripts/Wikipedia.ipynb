# %%
import pandas as pd
nasdaq_100_file_path = 'nasdaq100_data.csv'

# %%
nasdaq_100 = pd.read_csv(nasdaq_100_file_path)
nasdaq_100[['Ticker', 'Exchange', 'Sector', 'Industry']].head()
# Out:
#   Ticker Exchange                  Sector                    Industry
# 0   CPRT   NASDAQ       Consumer Cyclical    Auto & Truck Dealerships
# 1   AAPL   NASDAQ              Technology        Consumer Electronics
# 2   AMGN   NASDAQ              Healthcare  Drug Manufacturers—General
# 3  CMCSA   NASDAQ  Communication Services            Telecom Services
# 4   INTC   NASDAQ              Technology              Semiconductors

# %%
x = list(nasdaq_100.Ticker)
x
# Out:
# ['CPRT',
#  'AAPL',
#  'AMGN',
#  'CMCSA',
#  'INTC',
#  'KLAC',
#  'PCAR',
#  'CTAS',
#  'PAYX',
#  'LRCX',
#  'ADSK',
#  'ROST',
#  'MNST',
#  'MSFT',
#  'ADBE',
#  'FISV',
#  'FAST',
#  'EA',
#  'CSCO',
#  'REGN',
#  'IDXX',
#  'VRTX',
#  'BIIB',
#  'ODFL',
#  'QCOM',
#  'GILD',
#  'SNPS',
#  'SBUX',
#  'SIRI',
#  'INTU',
#  'MCHP',
#  'ORLY',
#  'DLTR',
#  'ASML',
#  'ANSS',
#  'CTSH',
#  'CSGP',
#  'EBAY',
#  'BKNG',
#  'ISRG',
#  'MRVL',
#  'ILMN',
#  'ADI',
#  'AEP',
#  'AMD',
#  'CDNS',
#  'CSX',
#  'HON',
#  'MU',
#  'XEL',
#  'EXC',
#  'PEP',
#  'TXN',
#  'WBA',
#  'ALGN',
#  'SGEN',
#  'MDLZ',
#  'NFLX',
#  'GOOGL',
#  'DXCM',
#  'TMUS',
#  'MELI',
#  'ATVI',
#  'AVGO',
#  'VRSK',
#  'FTNT',
#  'CHTR',
#  'TSLA',
#  'NXPI',
#  'ENPH',
#  'FANG',
#  'META',
#  'PANW',
#  'WDAY',
#  'GOOG',
#  'JD',
#  'PYPL',
#  'KHC',
#  'TEAM',
#  'BKR',
#  'ZS',
#  'PDD',
#  'MRNA',
#  'CRWD',
#  'ZM',
#  'DDOG',
#  'AZN',
#  'LULU',
#  'CEG',
#  'RIVN',
#  'GFS',
#  'ABNB',
#  'WBD',
#  'COST',
#  'KDP',
#  'LCID',
#  'ADP',
#  'MAR',
#  'AMZN',
#  'AMAT']

# %%
{
    'CPRT': 'Copart Inc.',
    'AAPL': 'Apple Inc.',
    'AMGN': 'Amgen Inc.',
    'CMCSA': 'Comcast Corporation',
    'INTC': 'Intel Corporation',
    'KLAC': 'KLA Corporation',
    'PCAR': 'PACCAR Inc',
    'CTAS': 'Cintas Corporation',
    'PAYX': 'Paychex, Inc.',
    'LRCX': 'Lam Research Corporation',
    'ADSK': 'Autodesk, Inc.',
    'ROST': 'Ross Stores, Inc.',
    'MNST': 'Monster Beverage Corporation',
    'MSFT': 'Microsoft Corporation',
    'ADBE': 'Adobe Inc.',
    'FISV': 'Fiserv, Inc.',
    'FAST': 'Fastenal Company',
    'EA': 'Electronic Arts Inc.',
    'CSCO': 'Cisco Systems, Inc.',
    'REGN': 'Regeneron Pharmaceuticals, Inc.',
    'IDXX': 'IDEXX Laboratories, Inc.',
    'VRTX': 'Vertex Pharmaceuticals Incorporated',
    'BIIB': 'Biogen Inc.',
    'ODFL': 'Old Dominion Freight Line, Inc.',
    'QCOM': 'QUALCOMM Incorporated',
    'GILD': 'Gilead Sciences, Inc.',
    'SNPS': 'Synopsys, Inc.',
    'SBUX': 'Starbucks Corporation',
    'SIRI': 'Sirius XM Holdings Inc.',
    'INTU': 'Intuit Inc.',
    'MCHP': 'Microchip Technology Incorporated',
    'ORLY': 'O Reilly Automotive, Inc.',
    'DLTR': 'Dollar Tree, Inc.',
    'ASML': 'ASML Holding N.V.',
    'ANSS': 'ANSYS, Inc.',
    'CTSH': 'Cognizant Technology Solutions Corporation',
    'CSGP': 'CoStar Group, Inc.',
    'EBAY': 'eBay Inc.',
    'BKNG': 'Booking Holdings Inc.',
    'ISRG': 'Intuitive Surgical, Inc.',
    'MRVL': 'Marvell Technology Group Ltd.',
    'ILMN': 'Illumina, Inc.',
    'ADI': 'Analog Devices, Inc.',
    'AEP': 'American Electric Power Company, Inc.',
    'AMD': 'Advanced Micro Devices, Inc.',
    'CDNS': 'Cadence Design Systems, Inc.',
    'CSX': 'CSX Corporation',
    'HON': 'Honeywell International Inc.',
    'MU': 'Micron Technology, Inc.',
    'XEL': 'Xcel Energy Inc.',
    'EXC': 'Exelon Corporation',
    'PEP': 'PepsiCo, Inc.',
    'TXN': 'Texas Instruments Incorporated',
    'WBA': 'Walgreens Boots Alliance, Inc.',
    'ALGN': 'Align Technology, Inc.',
    'SGEN': 'Seagen Inc.',
    'MDLZ': 'Mondelez International, Inc.',
    'NFLX': 'Netflix, Inc.',
    'GOOGL': 'Alphabet Inc.',
    'DXCM': 'DexCom, Inc.',
    'TMUS': 'T-Mobile US, Inc.',
    'MELI': 'MercadoLibre, Inc.',
    'ATVI': 'Activision Blizzard, Inc.',
    'AVGO': 'Broadcom Inc.',
    'VRSK': 'Verisk Analytics, Inc.',
    'FTNT': 'Fortinet, Inc.',
    'TSLA': 'Tesla Inc',
    'NXPI': 'NXP Semiconductors NV',
    'ENPH': 'Enphase Energy Inc',
    'FANG': 'Diamondback Energy Inc',
    'META': 'Metamaterial Inc',
    'PANW': 'Palo Alto Networks Inc',
    'WDAY': 'Workday Inc',
    'GOOG': 'Alphabet Inc',
    'JD': 'JD.com Inc',
    'PYPL': 'PayPal Holdings Inc',
    'KHC': 'Kraft Heinz Co',
    'TEAM': 'Atlassian Corp Plc',
    'BKR': 'Baker Hughes Co',
    'ZS': 'Zscaler Inc',
    'PDD': 'Pinduoduo Inc',
    'MRNA': 'Moderna Inc',
    'CRWD': 'CrowdStrike Holdings Inc',
    'ZM': 'Zoom Video Communications Inc',
    'DDOG': 'Datadog Inc',
    'AZN': 'AstraZeneca PLC',
    'LULU': 'Lululemon Athletica Inc',
    'CEG': 'Constellation Energy Group Inc',
    'RIVN': 'Rivian Automotive Inc',
    'GFS': 'First American Government Securities Inc',
    'ABNB': 'Airbnb Inc',
    'WBD': 'Weibo Corp',
    'COST': 'Costco Wholesale Corp',
    'KDP': 'Keurig Dr Pepper Inc',
    'LCID': 'Lucid Group Inc',
    'ADP': 'Automatic Data Processing Inc',
    'MAR': 'Marriott International Inc',
    'AMZN': 'Amazon.com Inc',
    'AMAT': 'Applied Materials Inc'
}
# Out:
#   File "C:\Users\RAUNAK~1\AppData\Local\Temp/ipykernel_11440/4164270713.py", line 67
#     'FTNT': 'Fortinet, Inc.',
#                              ^
# SyntaxError: unexpected EOF while parsing

# %%
# Out:
# ADBE

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\RAUNAK~1\AppData\Local\Temp/ipykernel_11440/3491993189.py in <module>
#       2
#       3 # Find the company name
# ----> 4 company_name = tr.find_all('a')[1].string
#       5
#       6 # Find the market capitalization
#
# IndexError: list index out of range
